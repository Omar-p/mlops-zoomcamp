# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet')

# %%
len(df.columns)
# Out:
# 19

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
((df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() / 60).std()
# Out:
# 42.594351241920904

# %%
df['trip_duration'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() / 60

# %%
trips_1_to_60_min = df[(df['trip_duration'] >= 1) & (df['trip_duration'] <= 60)]

# %%
(len(trips_1_to_60_min) / len(df)) * 100
# Out:
# 98.1220282212598

# %%
import pandas as pd

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet')

# %%
location_ids = df[['PULocationID', 'DOLocationID']].astype(str).to_dict(orient='records')

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
vectorizer = DictVectorizer(sparse=False)

# %%
feature_matrix = vectorizer.fit_transform(location_ids)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 feature_matrix = vectorizer.fit_transform(location_ids)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/_dict_vectorizer.py:313, in DictVectorizer.fit_transform(self, X, y)
#     290 def fit_transform(self, X, y=None):
#     291     """Learn a list of feature name -> indices mappings and transform X.
#     292
#     293     Like fit(X) followed by transform(X), but does not require
#    (...)
#     311         Feature vectors; always 2-d.
#     312     """
# --> 313     return self._transform(X, fitting=True)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/_dict_vectorizer.py:282, in DictVectorizer._transform(self, X, fitting)
#     280     result_matrix.sort_indices()
#     281 else:
# ...

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
dv = DictVectorizer(sparse=False)

# %%
feature_matrix = dv.fit_transform(data_dicts)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 feature_matrix = dv.fit_transform(data_dicts)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/_dict_vectorizer.py:313, in DictVectorizer.fit_transform(self, X, y)
#     290 def fit_transform(self, X, y=None):
#     291     """Learn a list of feature name -> indices mappings and transform X.
#     292
#     293     Like fit(X) followed by transform(X), but does not require
#    (...)
#     311         Feature vectors; always 2-d.
#     312     """
# --> 313     return self._transform(X, fitting=True)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/_dict_vectorizer.py:282, in DictVectorizer._transform(self, X, fitting)
#     280     result_matrix.sort_indices()
#     281 else:
# --> 282     result_matrix = result_matrix.toarray()
# ...

# %%
feature_matrix = dv.fit_transform(data_dicts)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 feature_matrix = dv.fit_transform(data_dicts)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/_dict_vectorizer.py:313, in DictVectorizer.fit_transform(self, X, y)
#     290 def fit_transform(self, X, y=None):
#     291     """Learn a list of feature name -> indices mappings and transform X.
#     292
#     293     Like fit(X) followed by transform(X), but does not require
#    (...)
#     311         Feature vectors; always 2-d.
#     312     """
# --> 313     return self._transform(X, fitting=True)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/_dict_vectorizer.py:243, in DictVectorizer._transform(self, X, fitting)
#     232     self._add_iterable_element(
#     233         f,
#     234         v,
#    (...)
# ...

# %%
january_df = df[df['tpep_pickup_datetime'].dt.month == 1]

# %%
num_columns = feature_matrix.shape[1]

# %%
num_columns

# %%
print(f'The dimensionality of the feature matrix is: {num_columns} columns')

# %%
january_df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
january_df.tail()
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 2964618         1  2024-01-31 23:18:48   2024-01-31 23:38:05              NaN
# 2964619         2  2024-01-31 23:45:59   2024-01-31 23:54:36              NaN
# 2964620         1  2024-01-31 23:13:07   2024-01-31 23:27:52              NaN
# 2964621         2  2024-01-31 23:19:00   2024-01-31 23:38:00              NaN
# 2964622         2  2024-01-31 23:07:23   2024-01-31 23:25:14              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 2964618           3.90         NaN               None            90
# 2964619           3.18         NaN               None           107
# 2964620           4.00         NaN               None           114
# 2964621           3.33         NaN               None           211
# 2964622           3.06         NaN               None           107
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
((january_df['tpep_dropoff_datetime'] - january_df['tpep_pickup_datetime']).dt.total_seconds() / 60).std()
# Out:
# 34.30123871238017

# %%
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])

# %%
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# %%
january_df = df[df['tpep_pickup_datetime'].dt.month == 1]

# %%
january_df['trip_duration_minutes'] = (january_df['tpep_dropoff_datetime'] - january_df['tpep_pickup_datetime']).dt.total_seconds() / 60
# Out:
# /tmp/ipykernel_15759/3068739215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   january_df['trip_duration_minutes'] = (january_df['tpep_dropoff_datetime'] - january_df['tpep_pickup_datetime']).dt.total_seconds() / 60

# %%
std_trip_duration_january = january_df['trip_duration_minutes'].std()

# %%
std_trip_duration_january
# Out:
# 34.85113736077084

# %%
df.tail()
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 2964619         2  2024-01-31 23:45:59   2024-01-31 23:54:36              NaN
# 2964620         1  2024-01-31 23:13:07   2024-01-31 23:27:52              NaN
# 2964621         2  2024-01-31 23:19:00   2024-01-31 23:38:00              NaN
# 2964622         2  2024-01-31 23:07:23   2024-01-31 23:25:14              NaN
# 2964623         1  2024-01-31 23:58:25   2024-02-01 00:13:30              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 2964619           3.18         NaN               None           107
# 2964620           4.00         NaN               None           114
# 2964621           3.33         NaN               None           211
# 2964622           3.06         NaN               None           107
# 2964623           8.10         NaN               None           138
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# Filter the DataFrame to include only rows where the pickup datetime is in January
january_df = df[df['tpep_pickup_datetime'].dt.month == 1]

# Calculate the difference in minutes for the filtered DataFrame
january_df['trip_duration_minutes'] = (january_df['tpep_dropoff_datetime'] - january_df['tpep_pickup_datetime']).dt.total_seconds() / 60

# Calculate the standard deviation of the trip duration in minutes for January
std_trip_duration_january = january_df['trip_duration_minutes'].std()

std_trip_duration_january
# Out:
# /tmp/ipykernel_15759/258761708.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   january_df['trip_duration_minutes'] = (january_df['tpep_dropoff_datetime'] - january_df['tpep_pickup_datetime']).dt.total_seconds() / 60
# 34.85113736077084

# %%
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# Calculate the trip duration in minutes
df['trip_duration_minutes'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() / 60

# Filter the DataFrame to keep only records where the trip duration is between 1 and 60 minutes
filtered_df = df[(df['trip_duration_minutes'] >= 1) & (df['trip_duration_minutes'] <= 60)]

# Calculate the fraction of records left
fraction_left = len(filtered_df) / len(df)

fraction_left
# Out:
# 0.9778326020432945

# %%
df['PULocationID'] = df['PULocationID'].astype(str)
df['DOLocationID'] = df['DOLocationID'].astype(str)

# Turn the DataFrame into a list of dictionaries
dicts = df.to_dict(orient='records')

# Fit a dictionary vectorizer
dv = DictVectorizer(sparse=False)
X = dv.fit_transform(dicts)

# Get the dimensionality of the matrix
dimensionality = X.shape[1]

dimensionality

# %%
dimensionality

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-01.parquet')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-01.parquet')
#
# NameError: name 'pd' is not defined

# %%
dimensionality
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 dimensionality
#
# NameError: name 'dimensionality' is not defined

# %%
import pandas as pd
from sklearn.feature_extraction import DictVectorizer

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...           ...                  ...                   ...              ...
# 2964619         2  2024-01-31 23:45:59   2024-01-31 23:54:36              NaN
# 2964620         1  2024-01-31 23:13:07   2024-01-31 23:27:52              NaN
# 2964621         2  2024-01-31 23:19:00   2024-01-31 23:38:00              NaN
# 2964622         2  2024-01-31 23:07:23   2024-01-31 23:25:14              NaN
# 2964623         1  2024-01-31 23:58:25   2024-02-01 00:13:30              NaN
#
# ...

# %%
df['PULocationID'] = df['PULocationID'].astype(str)
df['DOLocationID'] = df['DOLocationID'].astype(str)

# Turn the DataFrame into a list of dictionaries
dicts = df[['PULocationID', 'DOLocationID']].to_dict(orient='records')

# Fit a dictionary vectorizer
dv = DictVectorizer(sparse=False)
X = dv.fit_transform(dicts)

# Get the dimensionality of the matrix
dimensionality = X.shape[1]

dimensionality
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [14], in <cell line: 9>()
#       7 # Fit a dictionary vectorizer
#       8 dv = DictVectorizer(sparse=False)
# ----> 9 X = dv.fit_transform(dicts)
#      11 # Get the dimensionality of the matrix
#      12 dimensionality = X.shape[1]
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/_dict_vectorizer.py:313, in DictVectorizer.fit_transform(self, X, y)
#     290 def fit_transform(self, X, y=None):
#     291     """Learn a list of feature name -> indices mappings and transform X.
#     292
#     293     Like fit(X) followed by transform(X), but does not require
#    (...)
#     311         Feature vectors; always 2-d.
#     312     """
# --> 313     return self._transform(X, fitting=True)
#
# ...

# %%
dimensionality

# %%
print(dimensionality)

# %%
 X.shape[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 X.shape[1]
#
# NameError: name 'X' is not defined

# %%
df['PULocationID'] = df['PULocationID'].astype(str)
df['DOLocationID'] = df['DOLocationID'].astype(str)

# Turn the DataFrame into a list of dictionaries
dicts = df[['PULocationID', 'DOLocationID']].to_dict(orient='records')

# Fit a dictionary vectorizer
dv = DictVectorizer(sparse=False)
X = dv.fit_transform(dicts)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [16], in <cell line: 9>()
#       7 # Fit a dictionary vectorizer
#       8 dv = DictVectorizer(sparse=False)
# ----> 9 X = dv.fit_transform(dicts)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/_dict_vectorizer.py:313, in DictVectorizer.fit_transform(self, X, y)
#     290 def fit_transform(self, X, y=None):
#     291     """Learn a list of feature name -> indices mappings and transform X.
#     292
#     293     Like fit(X) followed by transform(X), but does not require
#    (...)
#     311         Feature vectors; always 2-d.
#     312     """
# --> 313     return self._transform(X, fitting=True)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/_dict_vectorizer.py:282, in DictVectorizer._transform(self, X, fitting)
#     280     result_matrix.sort_indices()
# ...

# %%
X.shape[1]
